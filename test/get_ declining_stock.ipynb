# %%
import sys
sys.path.append("../utils/")
import compete_banker
import date_util

# %%
start_date = "20191014"
end_date = "20191018"
stock_list = []

date_range = date_util.get_work_day_range(start_date, end_date)

for date in date_range:
    stock = compete_banker.get_declining_stock(date, ready=True)
    stock_list.append(stock)

stock_list

# %%
date = "20191008"
stock = compete_banker.get_declining_stock(date, times=0.5, ready=True)

# %%
stock
# Out:
# ['000157.SZ',
#  '000413.SZ',
#  '000422.SZ',
#  '000546.SZ',
#  '000598.SZ',
#  '000611.SZ',
#  '000670.SZ',
#  '000707.SZ',
#  '000757.SZ',
#  '000785.SZ',
#  '000806.SZ',
#  '000861.SZ',
#  '000869.SZ',
#  '000875.SZ',
#  '000931.SZ',
#  '000961.SZ',
#  '002016.SZ',
#  '002058.SZ',
#  '002072.SZ',
#  '002086.SZ',
#  '002096.SZ',
#  '002117.SZ',
#  '002137.SZ',
#  '002142.SZ',
#  '002259.SZ',
#  '002333.SZ',
#  '002372.SZ',
#  '002424.SZ',
#  '002461.SZ',
#  '002466.SZ',
#  '002489.SZ',
#  '002496.SZ',
#  '002501.SZ',
#  '002504.SZ',
#  '002506.SZ',
#  '002512.SZ',
#  '002534.SZ',
#  '002539.SZ',
#  '002541.SZ',
#  '002569.SZ',
#  '002575.SZ',
#  '002627.SZ',
#  '002650.SZ',
#  '002651.SZ',
#  '002671.SZ',
#  '002685.SZ',
#  '002686.SZ',
#  '002693.SZ',
#  '002695.SZ',
#  '002700.SZ',
#  '002728.SZ',
#  '002741.SZ',
#  '002756.SZ',
#  '002779.SZ',
#  '002798.SZ',
#  '002805.SZ',
#  '002873.SZ',
#  '002879.SZ',
#  '002891.SZ',
#  '002893.SZ',
#  '600048.SH',
#  '600070.SH',
# ...
