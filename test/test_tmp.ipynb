# %%
import pandas as pd
import os
import numpy as np
import tushare as ts

import sys
sys.path.append("../utils/")
import date_util
import enter_util
import plot_util
import token_util

# %%
date = "20191108"
date, raw_choose = enter_util.get_weekk_condidate_stock(date)
test_choose_list = enter_util.get_condidate_stock(date, raw_choose)

# %%
choose_data = enter_util.enter_for_plot(test_choose_list)

# %%
test_choose_list
# Out:
#    index stock_code trade_date   name   dif_dea  revenue_mean  vol_mean_20  \
# 0   4003  000810.SZ   20191108   创维数字  0.155825      0.934227     2.586720
# 1   1116  603338.SH   20191108   浙江鼎力  0.732182      1.790608    -0.705165
# 2    321  603713.SH   20191108   密尔克卫  1.657615      0.894595    -0.687649
# 3   1067  002755.SZ   20191108    奥赛康  1.791427      0.156231    -0.390242
# 4   4003  600783.SH   20191108   鲁信创投 -0.452256     -1.344049     0.429296
# 5   2317  002292.SZ   20191108   奥飞娱乐 -0.095731     -0.132990     0.983233
# 6    777  002810.SZ   20191108   山东赫达 -0.255259      0.375470    -0.291620
# 7   1129  603020.SH   20191108   爱普股份 -0.824104      0.069021    -0.532532
# 8   2283  002420.SZ   20191108  *ST毅昌 -0.744472     -0.719236    -0.461787
# 9    680  002843.SZ   20191108   泰嘉股份 -0.842209     -0.482315    -0.567268
# 10  2825  002216.SZ   20191108   三全食品 -1.123018     -1.541562    -0.362986
#
#     vol_discount_mean  rank_factor
# 0           -0.743496     0.555526
# 1            0.772790     0.501771
# 2           -0.182036     0.457537
# 3           -0.996831     0.283448
# 4            2.561997     0.260975
# 5           -0.584976     0.030984
# 6           -0.549169    -0.188415
# 7            0.398360    -0.263712
# 8            0.174749    -0.388634
# 9           -0.604480    -0.559360
# 10          -0.246908    -0.690119

# %%
enter_true, enter_false, enter_discount = plot_util.plot_enter(choose_data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-31-3cecb9922584> in <module>
# ----> 1 enter_true, enter_false, enter_discount = plot_util.plot_enter(choose_data)
#
# ~\Desktop\git\auto_stocken\utils\plot_util.py in plot_enter(golden_port, true_port, plot_date)
#      33
#      34             # 如果true_port天之后快线还在慢线上方，则表示正确入场，否则表示错误入场
# ---> 35             quick_value = golden_port["data"][num_plot-1].iloc[:,0].values[true_port-1]
#      36             slow_value = golden_port["data"][num_plot-1].iloc[:,1].values[true_port-1]
#      37             if quick_value > slow_value:
#
# IndexError: index 4 is out of bounds for axis 0 with size 1

# %%
enter_discount
