# %%
import pandas as pd
import os
import numpy as np

import sys
sys.path.append("../utils/")
import date_util
import enter_util
import plot_util

# %%
date = "20191107"
date, raw_choose = enter_util.get_weekk_condidate_stock(date)
test_choose_list = enter_util.get_condidate_stock(date, raw_choose)

# %%
test_choose_list
# Out:
#    index stock_code trade_date  name   dif_dea  his_macd_discount  \
# 0   4002  000671.SZ   20191107   阳光城  1.482976          -0.332975
# 1   3825  600015.SH   20191107  华夏银行  0.314970          -1.568490
# 2   4002  600851.SH   20191107  海欣股份  1.492770           0.238514
# 3   2289  002381.SZ   20191107  双箭股份  0.089558           1.360541
# 4   2406  002276.SZ   20191107  万马股份 -0.628325           1.430114
# 5   4002  000628.SZ   20191107  高新发展  0.246223          -0.603680
# 6   2273  002424.SZ   20191107  贵州百灵  0.607352          -1.461653
# 7   3129  002083.SZ   20191107  孚日股份 -0.109313           0.141840
# 8   1182  002737.SZ   20191107  葵花药业 -1.371137          -0.385911
# 9   4002  600724.SH   20191107  宁波富达 -1.557999           0.358827
# 10  3736  600403.SH   20191107  大有能源 -0.567076           0.822872
#
#     vol_mean_20  vol_discount_mean  rank_factor
# 0      1.601928           0.654899     1.124100
# 1      1.511404          -0.003389     0.346143
# 2     -0.714433          -0.867032     0.225593
# 3     -0.296813           0.476813     0.216877
# 4      1.378482          -0.079973     0.216309
# 5     -0.848934           0.590234    -0.026554
# 6     -0.109415          -0.621709    -0.086005
# 7     -0.151576          -0.184683    -0.113606
# 8     -0.868624           1.737001    -0.369952
# 9     -0.830322           0.443283    -0.684076
# 10    -0.671698          -2.145443    -0.848828

# %%
choose_data = enter_util.enter_for_plot(test_choose_list)

# %%
enter_true, enter_false, enter_discount = plot_util.plot_enter(choose_data)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-5-3cecb9922584> in <module>
# ----> 1 enter_true, enter_false, enter_discount = plot_util.plot_enter(choose_data)
#
# ~\Desktop\git\auto_stocken\utils\plot_util.py in plot_enter(golden_port, true_port, plot_date)
#      33
#      34             # 如果true_port天之后快线还在慢线上方，则表示正确入场，否则表示错误入场
# ---> 35             quick_value = golden_port["data"][num_plot-1].iloc[:,0].values[true_port-1]
#      36             slow_value = golden_port["data"][num_plot-1].iloc[:,1].values[true_port-1]
#      37             if quick_value > slow_value:
#
# IndexError: index 4 is out of bounds for axis 0 with size 1

# %%
enter_discount
